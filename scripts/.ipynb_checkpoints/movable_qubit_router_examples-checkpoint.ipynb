# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))


import cococo.layouts as layouts
import cococo.utils_routing as utils
import cococo.circuit_construction as circuit_construction
import cococo.internal_testing as internal_testing
import plotting

# %% [markdown]
# ## Example for Router with Movable Qubits
#
# ### Choose Layout

# %%
layout_type = "triple"
m = 4
n = 4
factories = []
remove_edges = False
g, data_qubit_locs, factory_ring = layouts.gen_layout_scalable(layout_type, m, n, factories, remove_edges)
layout = {i: j for i,j in enumerate(data_qubit_locs)}
t=2 #mock because we have only cnots here in the example

# %%
plotting.plot_lattice_paths(g, {}, {}, layout, factories, size = (18,8))
# Out:
# /mnt/c/Users/faceb/OneDrive/Desktop/TUM_CSE/master_thesis/Code/cococo_hs/scripts/plotting.py:184: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Choose Circuit

# %%
q = len(data_qubit_locs)
j = 8
num_gates = q*2
dag, pairs = circuit_construction.create_random_sequential_circuit_dag(j, q, num_gates, )

# %% [markdown]
# ### Run Standard Router with Standard Layout

# %%
terminal_pairs = layouts.translate_layout_circuit(pairs, layout) #let's stick to the simple layout

# %%
router = utils.BasicRouter(g, data_qubit_locs, factories, valid_path = "cc", t=t, metric = "exact", use_dag = True)
layers = router.split_layer_terminal_pairs(terminal_pairs)
vdp_layers, _ = router.find_total_vdp_layers_dyn(layers, data_qubit_locs, router.factory_times, layout, testing = True)
print("Len of schedule without teleportation: ", len(vdp_layers))
# Out:
# 2026-04-22 15:04:15,245 [INFO] root: stim test succeeded for standard routing (:
# 2026-04-22 15:04:15,247 [INFO] root: no duplicates found in standard routing (:
# 2026-04-22 15:04:15,251 [INFO] root: paths do not occupy logical pos (:
# 2026-04-22 15:04:15,252 [INFO] root: Reset times make sense, all good(:
# Len of schedule without teleportation:  51

# %% [markdown]
# ### Run Movable Qubits Router with Standard Initial Layout

# %%
router = utils.TeleportationRouter(g, data_qubit_locs, factories, valid_path="cc", t=t, metric="exact", use_dag = True, seed = 49218)
layers = router.split_layer_terminal_pairs(terminal_pairs)

max_iters = 100
T_start = 100.0
T_end = 0.1
alpha = 0.95
t=4 #mock value for cnot circuit
radius = 10
k_lookahead = 5
metric = "exact"

steiner_init_type = "full_random"
jump_harvesting = True
stimtest = True

reduce_steiner = True
idle_move_type = "later"

schedule, _ = router.optimize_layers(        
        terminal_pairs,
        layout,
        max_iters,
        T_start,
        T_end,
        alpha,
        radius = radius,
        k_lookahead = k_lookahead,
        steiner_init_type = steiner_init_type,
        jump_harvesting = jump_harvesting,
        reduce_steiner = reduce_steiner,
        idle_move_type = idle_move_type,
        reduce_init_steiner = False,
        stimtest = True)
# Out:
# 2026-04-22 15:09:53,682 [INFO] root: Iteration 0: |vdp_dict|=6, pushing |terminal_pairs_remainder|=2, remaining |layers|=24
# 2026-04-22 15:10:36,497 [INFO] root: Steiner found for this layer.
# 2026-04-22 15:10:36,498 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:10:40,954 [INFO] root: Complexity of Steiner could be reduced.
# 2026-04-22 15:10:41,405 [INFO] root: Iteration 1: |vdp_dict|=5, pushing |terminal_pairs_remainder|=2, remaining |layers|=20
# 2026-04-22 15:11:28,638 [INFO] root: Steiner found for this layer.
# 2026-04-22 15:11:28,639 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:11:30,634 [INFO] root: Complexity of Steiner could be reduced.
# 2026-04-22 15:11:31,183 [INFO] root: Iteration 2: |vdp_dict|=5, pushing |terminal_pairs_remainder|=1, remaining |layers|=16
# 2026-04-22 15:12:16,698 [INFO] root: Steiner found for this layer.
# 2026-04-22 15:12:16,699 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:12:16,970 [INFO] root: Complexity of Steiner could be reduced.
# 2026-04-22 15:12:17,355 [INFO] root: Iteration 3: |vdp_dict|=5, pushing |terminal_pairs_remainder|=0, remaining |layers|=12
# 2026-04-22 15:12:59,883 [INFO] root: No Steiner improvement possible in this layer.
# 2026-04-22 15:12:59,883 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:12:59,999 [INFO] root: Iteration 4: |vdp_dict|=5, pushing |terminal_pairs_remainder|=1, remaining |layers|=11
# 2026-04-22 15:13:00,011 [INFO] root: No idling path back could be found for danger qubit (11, 3)
# 2026-04-22 15:13:35,619 [INFO] root: Steiner found for this layer.
# 2026-04-22 15:13:35,619 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:13:38,422 [INFO] root: Complexity of Steiner could be reduced.
# 2026-04-22 15:13:38,782 [INFO] root: Iteration 5: |vdp_dict|=5, pushing |terminal_pairs_remainder|=0, remaining |layers|=7
# 2026-04-22 15:13:38,793 [INFO] root: No idling path back could be found for danger qubit (26, 4)
# 2026-04-22 15:14:27,866 [INFO] root: Steiner found for this layer.
# 2026-04-22 15:14:27,867 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:14:43,851 [INFO] root: Iteration 6: |vdp_dict|=5, pushing |terminal_pairs_remainder|=2, remaining |layers|=2
# 2026-04-22 15:14:56,984 [INFO] root: Steiner found for this layer.
# 2026-04-22 15:14:56,986 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-04-22 15:14:59,813 [INFO] root: Complexity of Steiner could be reduced.
# 2026-04-22 15:14:59,954 [INFO] root: Iteration 7: |vdp_dict|=5, pushing |terminal_pairs_remainder|=0, remaining |layers|=1
# 2026-04-22 15:14:59,972 [INFO] root: Number of gates in schedule and initial terminal_pairs coincides (:
# 2026-04-22 15:14:59,983 [INFO] root: Stim test succeeded: Pushing gates does not cause trouble(:
# 2026-04-22 15:14:59,985 [INFO] root: No duplicates found in any layer of the schedule - hence all good(:
# 2026-04-22 15:14:59,990 [INFO] root: No path/tree is placed on a logical pos. All good(:
# 2026-04-22 15:14:59,991 [INFO] root: All good with the reset times (:

# %%
print("Len of schedule with teleport router: ", len(schedule))
# Out:
# Len of schedule with teleport router:  37

# %%
print("Reduction Delta: ", len(vdp_layers) - len(schedule))
# Out:
# Reduction Delta:  14
