# %%
import sys
from pathlib import Path

import matplotlib as mpl
#mpl.use("Agg")  # headless: this script only saves animations, never shows a GUI window

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

import cococo.layouts as layouts
import cococo.utils_routing as utils
import cococo.circuit_construction as circuit_construction
import cococo.internal_testing as internal_testing
from cococo.animations import make_fine_sa_routing_animation

from datetime import datetime

from IPython.display import HTML
from cococo.animations import make_clean_routing_html_animation

# %%
layout_type = "single"
m = 4
n = 4
factories = []
remove_edges = False
g, data_qubit_locs, factory_ring = layouts.gen_layout_scalable(layout_type, m, n, factories, remove_edges)
layout = {i: j for i,j in enumerate(data_qubit_locs)}
t=2

# %%
print(layout)
# Out:
# {0: (2, 0), 1: (6, 0), 2: (10, 0), 3: (14, 0), 4: (3, 2), 5: (7, 2), 6: (11, 2), 7: (15, 2), 8: (4, 4), 9: (8, 4), 10: (12, 4), 11: (16, 4), 12: (5, 6), 13: (9, 6), 14: (13, 6), 15: (17, 6)}

# %%
layout_rev = {j:i for i,j in enumerate(data_qubit_locs)}
def qubit(pos):
    return layout_rev[pos]

# %%
q = len(data_qubit_locs)
print("number of data qubits: ", q)
j = 8
num_gates = 4 * q
max_overlap = 5
# Out:
# number of data qubits:  16

# %%
seed = 1
dag, pairs = circuit_construction.create_random_sequential_circuit_dag(j, q, num_gates, seed) # at least num_gates gates
#print("pairs: ", pairs)
print("number of gates: ", len(pairs))
# Out:
# number of gates:  64

# %%
## standard method

# %%
terminal_pairs = layouts.translate_layout_circuit(pairs, layout) 
#print("terminal pairs: ", terminal_pairs)

router = utils.BasicRouter(g, data_qubit_locs, factories, valid_path = "cc", t=t, metric = "exact", use_dag = True)
# each layer has disjoint logical support, however it doesn't guarantee that all those gates can be physically routed at the same time on the lattice
layers = router.split_layer_terminal_pairs(terminal_pairs)
vdp_layers, _ = router.find_total_vdp_layers_dyn(layers, data_qubit_locs, router.factory_times, layout, testing = True)
# Out:
# 2026-08-05 10:43:18,415 [INFO] root: stim test succeeded for standard routing (:
# 2026-08-05 10:43:18,416 [INFO] root: no duplicates found in standard routing (:
# 2026-08-05 10:43:18,417 [INFO] root: paths do not occupy logical pos (:
# 2026-08-05 10:43:18,417 [INFO] root: Reset times make sense, all good(:

# %%
#for pair in terminal_pairs:
#    print(qubit(pair[0]), qubit(pair[1]))

# %%
for i, layer in enumerate(layers):
    #print(i, layer, "\n")
    layer_trans =[]
    for gate in layer:
        layer_trans.append((qubit(gate[0]), qubit(gate[1])))
    #print(i, layer_trans , "\n")

# %%
print("Len of schedule (standard): ", len(vdp_layers))
# Out:
# Len of schedule (standard):  11

# %%
## Fine-grained method

# %%
router2 = utils.TeleportationRouter(g, data_qubit_locs, factories, valid_path="cc", t=t, metric="exact", use_dag = True, seed =  49218  )
router2.find_total_fine_grained_vdp_dyn(layers, data_qubit_locs, None, layout = layout, max_overlap = max_overlap, overlap_type = "strict_k", testing = True)
print("Len of schedule (fine grained): ", len(router2.routes_by_layer))
# Out:
# 2026-08-05 10:43:18,598 [INFO] root: stim test succeeded for fine grained routing (:
# 2026-08-05 10:43:18,599 [INFO] root: no duplicate nodes in fine grained routing (:
# 2026-08-05 10:43:18,601 [INFO] root: paths do not occupy logical pos (:
# Len of schedule (fine grained):  10

# %%
## Fine-grained + teleportation

# %%
max_iters = 100
T_start = 100.0
T_end = 0.1
alpha = 0.95
t=4 #mock value for cnot circuit
radius = 10
k_lookahead = 5
max_idle_teleport = 10
metric = "exact"

steiner_init_type = "full_random"
jump_harvesting = True
stimtest = True

reduce_teleport = False
idle_move_type = "later"

filename = f'../../Output_Files/schedule/schedule_{datetime.now().strftime("%Y-%m-%d_%H-%M-%S")}.pkl'

# %%
router4 = utils.TeleportationRouter(g, data_qubit_locs, factories, valid_path="cc", t=t, metric="exact", use_dag = True, seed =  49218  )
schedule, _ = router4.optimize_layers(        
        terminal_pairs,
        layout,
        max_iters,
        T_start,
        T_end,
        alpha,
        radius = radius,
        k_lookahead = k_lookahead,
        max_idle_teleport = max_idle_teleport,
        steiner_init_type = steiner_init_type,
        jump_harvesting = jump_harvesting,
        reduce_teleport = reduce_teleport,
        idle_move_type = idle_move_type,
        vdp_type = "fine_grained",
        overlap_type =  "strict_k",
        max_overlap = max_overlap,
        filename = filename,
        include_steiner_teleport = True,
        include_idle_teleport = False,
        reduce_init_steiner = True,
        reduce_init_idle = False, 
        stimtest = True,    
)
# Out:
# 2026-08-05 10:43:18,667 [INFO] root: Iteration 0: |vdp_dict|=7, pushing |terminal_pairs_remainder|=1, remaining |layers|=8
# 2026-08-05 10:43:25,384 [INFO] root: No Teleportation improvement possible in this layer.
# 2026-08-05 10:43:25,386 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-08-05 10:43:25,479 [INFO] root: Iteration 1: |vdp_dict|=7, pushing |terminal_pairs_remainder|=0, remaining |layers|=8
# 2026-08-05 10:43:33,619 [INFO] root: No Teleportation improvement possible in this layer.
# 2026-08-05 10:43:33,621 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-08-05 10:43:33,703 [INFO] root: Iteration 2: |vdp_dict|=6, pushing |terminal_pairs_remainder|=0, remaining |layers|=7
# 2026-08-05 10:43:41,667 [INFO] root: No Teleportation improvement possible in this layer.
# 2026-08-05 10:43:41,668 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-08-05 10:43:41,732 [INFO] root: Iteration 3: |vdp_dict|=6, pushing |terminal_pairs_remainder|=0, remaining |layers|=6
# 2026-08-05 10:43:49,475 [INFO] root: Teleportation found for this layer.
# 2026-08-05 10:43:49,476 [INFO] root: Final Temperature T = 5.920529e-01
# 2026-08-05 10:43:49,542 [INFO] root: Iteration 4: |vdp_dict|=8, pushing |terminal_pairs_remainder|=0, remaining |layers|=1
# 2026-08-05 10:43:49,553 [INFO] root: Number of gates in schedule and initial terminal_pairs coincides (:
# 2026-08-05 10:43:49,557 [INFO] root: Stim test succeeded: Pushing gates does not cause trouble(:
# 2026-08-05 10:43:49,558 [INFO] root: No shared-phase nodes in any fine-grained layer - all good(:
# 2026-08-05 10:43:49,559 [INFO] root: No overlapping steiner branches in any fine-grained layer - all good(:
# 2026-08-05 10:43:49,560 [INFO] root: No path/tree is placed on a logical pos. All good(:
# 2026-08-05 10:43:49,561 [INFO] root: All good with the reset times (:

# %%
for i, sch in enumerate(schedule):
    print("Layer ", i+1, " : ")
    print("Steiner: ", sch['steiner'])
    print("Idle telep: ", sch['idle_teleport'])
    print("Fine routes: ")
    for gate, route_info in sch['fine_routes'].items():
        print(gate)
# Out:
# Layer  1  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((3, 2), (10, 0))
# ((7, 2), (6, 0))
# ((4, 4), (14, 0))
# ((15, 2), (12, 4))
# ((16, 4), (8, 4))
# ((5, 6), (11, 2))
# ((17, 6), (13, 6))
# Layer  2  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((14, 0), (10, 0))
# ((11, 2), (6, 0))
# ((3, 2), (8, 4))
# ((12, 4), (16, 4))
# ((4, 4), (5, 6))
# ((2, 0), (9, 6))
# ((17, 6), (13, 6))
# Layer  3  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((14, 0), (11, 2))
# ((15, 2), (2, 0))
# ((8, 4), (3, 2))
# ((4, 4), (16, 4))
# ((9, 6), (7, 2))
# ((13, 6), (17, 6))
# Layer  4  :
# Steiner:  {((7, 2), (6, 0), (6, 1)): ([(7, 2), (7, 1), (6, 1), (6, 0)], [(6, 1)]), ((15, 2), (10, 0), (15, 3)): ([(15, 2), (15, 1), (14, 1), (13, 1), (12, 1), (11, 1), (10, 1), (10, 0)], [(13, 1), (13, 2), (14, 2), (14, 3), (15, 3)]), ((3, 2), (4, 4), (2, -1)): ([(3, 2), (4, 2), (4, 3), (3, 3), (3, 4), (4, 4)], [(4, 2), (5, 2), (5, 1), (4, 1), (4, 0), (3, 0), (3, -1), (2, -1)]), ((5, 6), (2, 0), (12, 0)): ([(5, 6), (5, 5), (4, 5), (3, 5), (2, 5), (2, 4), (3, 4), (3, 3), (2, 3), (2, 2), (1, 2), (1, 1), (2, 1), (2, 0)], [(5, 5), (6, 5), (6, 4), (7, 4), (7, 3), (8, 3), (8, 2), (9, 2), (9, 1), (8, 1), (8, 0), (9, 0), (9, -1), (10, -1), (11, -1), (11, 0), (12, 0)]), ((9, 6), (12, 4), (10, 2)): ([(9, 6), (9, 5), (10, 5), (10, 4), (11, 4), (12, 4)], [(11, 4), (11, 3), (10, 3), (10, 2)]), ((17, 6), (11, 2), (12, 3)): ([(17, 6), (17, 5), (16, 5), (15, 5), (14, 5), (14, 4), (13, 4), (13, 3), (12, 3), (12, 2), (11, 2)], [(12, 3)])}
# Idle telep:  {}
# Fine routes:
# ((7, 2), (6, 0))
# ((15, 2), (10, 0))
# ((3, 2), (4, 4))
# ((5, 6), (2, 0))
# ((9, 6), (12, 4))
# ((17, 6), (11, 2))
# Layer  5  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((7, 2), (14, 0))
# ((15, 2), (15, 3))
# ((4, 4), (2, -1))
# ((8, 4), (6, 1))
# ((16, 4), (10, 2))
# ((2, 0), (12, 0))
# ((9, 6), (13, 6))
# ((17, 6), (12, 3))
# Layer  6  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((15, 3), (6, 1))
# ((7, 2), (14, 0))
# ((10, 2), (15, 2))
# ((12, 0), (8, 4))
# ((9, 6), (2, 0))
# ((16, 4), (13, 6))
# ((4, 4), (17, 6))
# Layer  7  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((6, 1), (2, 0))
# ((14, 0), (12, 3))
# ((7, 2), (15, 2))
# ((15, 3), (16, 4))
# ((10, 2), (12, 0))
# ((9, 6), (8, 4))
# ((2, -1), (13, 6))
# Layer  8  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((15, 3), (2, -1))
# ((12, 3), (15, 2))
# ((8, 4), (6, 1))
# ((10, 2), (14, 0))
# ((16, 4), (2, 0))
# ((4, 4), (12, 0))
# ((7, 2), (9, 6))
# ((17, 6), (13, 6))
# Layer  9  :
# Steiner:  None
# Idle telep:  None
# Fine routes:
# ((2, 0), (2, -1))
# ((6, 1), (12, 3))
# ((15, 2), (7, 2))
# ((16, 4), (4, 4))
# ((15, 3), (12, 0))
# ((8, 4), (9, 6))
# ((13, 6), (14, 0))
# ((17, 6), (10, 2))

# %%
print("Len of schedule (fg+sa): ", len(schedule))
# Out:
# Len of schedule (fg+sa):  9

# %%
print("Reduction Delta: ", len(vdp_layers) - len(schedule))
# Out:
# Reduction Delta:  2

# %%
#Path("animation").mkdir(exist_ok=True)
#filename = f"../../Output_Files/animation/{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.html"

# combined animation: two-phase routing (frame A) + teleportation (frame B) per layer
#make_fine_sa_routing_animation(
#    router.g,
#    schedule,
#    initial_layout=layout,
#    factories=factories,
#    interval=900,
#    save_path=filename,
#    figsize=(18, 8),
#)
